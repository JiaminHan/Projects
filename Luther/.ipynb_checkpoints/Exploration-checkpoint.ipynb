# %%
import requests
from bs4 import BeautifulSoup

url = 'https://flightaware.com/live/airport/KSEA/departures'

response=requests.get(url)
page=response.text

soup=BeautifulSoup(page,"lxml")

# %%
response
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <title>2018 Yearly Box Office Results - Box Office Mojo</title>
# <meta content="2018, year, yearly, box, office, result, list, movie, movies, listing, listings, top movies, all time, film" name="keywords"/>
# <meta content="Yearly box office results for 2018." name="description"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/></head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
# ...

# %%
tables=soup.find_all("table")

rows=[row for row in tables[6].find_all('tr')]

#Just want to look at 1st 20 rows for now
rows=rows[1:20]
rows

# movies={}
# for row in rows:
#     items=row.find_all('td')
#     title=items[1].find('a')['href']
#     movies[title]=[i.text for i in items[1:]]
    
# movies
# Out:
# [<tr><td>
#  <select name="mojolinks1" onchange="MojoDrop1(this.form)" style="font-family: Verdana; font-size: 8pt">
#  <option selected="">Filter</option><option value="/yearly/chart/?view=releasedate&amp;view2=domestic&amp;yr=2018&amp;sort=gross&amp;order=DESC&amp;studio=a24.htm">A24</option>
#  <option value="/yearly/chart/?view=releasedate&amp;view2=domestic&amp;yr=2018&amp;sort=gross&amp;order=DESC&amp;studio=artaffects.htm">AAE</option>
#  <option value="/yearly/chart/?view=releasedate&amp;view2=domestic&amp;yr=2018&amp;sort=gross&amp;order=DESC&amp;studio=abramorama.htm">Abr.</option>
#  <option value="/yearly/chart/?view=releasedate&amp;view2=domestic&amp;yr=2018&amp;sort=gross&amp;order=DESC&amp;studio=atlas.htm">ADC</option>
#  <option value="/yearly/chart/?view=releasedate&amp;view2=domestic&amp;yr=2018&amp;sort=gross&amp;order=DESC&amp;studio=amazon.htm">Amazon</option>
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

import os
chromedriver = "/Users/Minmin/Downloads/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)

# %%
url = "https://flightaware.com/live/findflight/KSEA/KLAX"
driver.get(url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
